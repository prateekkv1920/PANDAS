# %%
import pandas as pd
df = pd.DataFrame(
{"a":[4,5,6],
"b":[7,8,9],
"c":[10,11,12]})
df
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
n=pd.Series([1,2,34,5,56,67,])
print(n)
# Out:
# 0     1
# 1     2
# 2    34
# 3     5
# 4    56
# 5    67
# dtype: int64

# %%
print(n[4])

print(n[2:4])

print(n[1:5:2])
# Out:
# 56
# 2    34
# 3     5
# dtype: int64
# 1    2
# 3    5
# dtype: int64

# %%
pf=pd.DataFrame([[4,5,6],[6,233,424],[2344,3124,1243]],index=["a","b","c"],columns=["a","b",'c'])
pf
# Out:
#       a     b     c
# a     4     5     6
# b     6   233   424
# c  2344  3124  1243

# %%
df
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]], 
index=[1, 2, 3], 
columns=['a', 'b', 'c'])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
import pandas as pd 
df = pd.DataFrame(
{"a" : [4 ,5, 6], 
"b" : [7, 8, 9], 
"c" : [10, 11, 12]}, 
index = pd.MultiIndex.from_tuples(
[('D', 1), ('D', 2),
('e', 2)], names=['N', 'v']))
df
# Out:
#      a  b   c
# N v
# D 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
import pandas as pd 
d = pd.DataFrame(
{"a" : [4 ,5, 6], 
"b" : [7, 8, 9], 
"c" : [10, 11, 12]}, 
index = pd.MultiIndex.from_tuples(
[('D', 1), ('D', 2),
('e', 2)], names=['N', 'V']))
d
# Out:
#      a  b   c
# N V
# D 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
d
# Out:
#      a  b   c
# N V
# D 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
df= (pd.melt(df)
.rename(columns={
'variable':'a', 
'value':'val'})
.query('val >= 2')
)
df
# Out:
#    a  val
# 0  a    4
# 1  a    5
# 2  a    6
# 3  b    7
# 4  b    8
# 5  b    9
# 6  c   10
# 7  c   11
# 8  c   12

# %%
len(df)
# Out:
# 9

# %%
d.shape
# Out:
# (3, 3)

# %%
d.nunique()
# Out:
# a    3
# b    3
# c    3
# dtype: int64

# %%
d.describe()
# Out:
#          a    b     c
# count  3.0  3.0   3.0
# mean   5.0  8.0  11.0
# std    1.0  1.0   1.0
# min    4.0  7.0  10.0
# 25%    4.5  7.5  10.5
# 50%    5.0  8.0  11.0
# 75%    5.5  8.5  11.5
# max    6.0  9.0  12.0

# %%
df.value_counts()
# Out:
# a  val
# a  4      1
#    5      1
#    6      1
# b  7      1
#    8      1
#    9      1
# c  10     1
#    11     1
#    12     1
# Name: count, dtype: int64

# %%
df.groupby(level="ind")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.groupby(level="ind")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
d.plot.hist()

# %%
df.

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\prate\\OneDrive\\Desktop\\data.csv.csv")
df
# Out:
#       1                2         3 Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2  1Ef7b82A4CAAD10   Preston        NaN
# 2     3  6F94879bDAfE5a6       Roy        NaN
# 3     4  5Cef8BFA16c5e3c     Linda        NaN
# 4     5  053d585Ab6b3159    Joanna        NaN
# ..  ...              ...       ...        ...
# 95   96  cb8E23e48d22Eae      Karl      Greer
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby(level="2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.groupby(level="2")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
df.describe()
# Out:
#                 1
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
min(df)
# Out:
# '1'

# %%
max(df)
# Out:
# 'Unnamed: 3'

# %%
pd.melt(df)
# Out:
#      variable                              value
# 0           1                                  1
# 1           1                                  2
# 2           1                                  3
# 3           1                                  4
# 4           1                                  5
# ...       ...                                ...
# 1195       12            http://hayes-perez.com/
# 1196       12         https://novak-allison.com/
# 1197       12              https://www.ross.com/
# 1198       12               http://watkins.info/
# 1199       12  http://www.hatfield-saunders.net/
#
# [1200 rows x 2 columns]

# %%
pd.concat([df,d])
# Out:
#         1                2         3 Unnamed: 3  \
# 0     1.0  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2.0  1Ef7b82A4CAAD10   Preston        NaN
# 2     3.0  6F94879bDAfE5a6       Roy        NaN
# 3     4.0  5Cef8BFA16c5e3c     Linda        NaN
# 4     5.0  053d585Ab6b3159    Joanna        NaN
# ..    ...              ...       ...        ...
# 95   96.0  cb8E23e48d22Eae      Karl      Greer
# 96   97.0  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98.0  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99.0  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100.0  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.pivot(columns=103,values=6.0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 103
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pd.concat([df,d],axis=1)
# Out:
#       1                2         3 Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2  1Ef7b82A4CAAD10   Preston        NaN
# 2     3  6F94879bDAfE5a6       Roy        NaN
# 3     4  5Cef8BFA16c5e3c     Linda        NaN
# 4     5  053d585Ab6b3159    Joanna        NaN
# ..  ...              ...       ...        ...
# 95   96  cb8E23e48d22Eae      Karl      Greer
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
pd.concat([df,d],axis=1)
# Out:
#       1                2         3 Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2  1Ef7b82A4CAAD10   Preston        NaN
# 2     3  6F94879bDAfE5a6       Roy        NaN
# 3     4  5Cef8BFA16c5e3c     Linda        NaN
# 4     5  053d585Ab6b3159    Joanna        NaN
# ..  ...              ...       ...        ...
# 95   96  cb8E23e48d22Eae      Karl      Greer
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
df.sort_index()
# Out:
#       1                2         3 Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2  1Ef7b82A4CAAD10   Preston        NaN
# 2     3  6F94879bDAfE5a6       Roy        NaN
# 3     4  5Cef8BFA16c5e3c     Linda        NaN
# 4     5  053d585Ab6b3159    Joanna        NaN
# ..  ...              ...       ...        ...
# 95   96  cb8E23e48d22Eae      Karl      Greer
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
df.reset_index()
# Out:
#     index    1                2         3 Unnamed: 3  \
# 0       0    1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1       1    2  1Ef7b82A4CAAD10   Preston        NaN
# 2       2    3  6F94879bDAfE5a6       Roy        NaN
# 3       3    4  5Cef8BFA16c5e3c     Linda        NaN
# 4       4    5  053d585Ab6b3159    Joanna        NaN
# ..    ...  ...              ...       ...        ...
# 95     95   96  cb8E23e48d22Eae      Karl      Greer
# 96     96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97     97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98     98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99     99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# ...

# %%
df.drop(columns=['9','8'])
# Out:
#       1                2         3 Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2  1Ef7b82A4CAAD10   Preston        NaN
# 2     3  6F94879bDAfE5a6       Roy        NaN
# 3     4  5Cef8BFA16c5e3c     Linda        NaN
# 4     5  053d585Ab6b3159    Joanna        NaN
# ..  ...              ...       ...        ...
# 95   96  cb8E23e48d22Eae      Karl      Greer
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
df[df.length>7]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12208\1080802534.py in ?()
# ----> 1 df[df.length>7]
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'length'

# %%
df.drop_duplicates()
# Out:
#       1                2         3 Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl        NaN
# 1     2  1Ef7b82A4CAAD10   Preston        NaN
# 2     3  6F94879bDAfE5a6       Roy        NaN
# 3     4  5Cef8BFA16c5e3c     Linda        NaN
# 4     5  053d585Ab6b3159    Joanna        NaN
# ..  ...              ...       ...        ...
# 95   96  cb8E23e48d22Eae      Karl      Greer
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  100  2354a0E336A91A1  Clarence     Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
df.sample(frac=0.5)
# Out:
#      1                2          3   Unnamed: 3                            5  \
# 30  31  64DCcDFaB9DFd4e       Jack         Tate  Acosta, Petersen and Morrow
# 12  13  e35426EbDEceaFF     Tracey         Mata               Graham-Francis
# 9   10  8C2811a503C7c5a   Michelle    Gallagher                 Beck-Hendrix
# 55  56  C6F2Fc6a7948a4e      Ralph         Haas                   Montes PLC
# 65  66  fF1b6c9E8Fbf1ff   Fernando      Lambert                 Church-Banks
# 94  95  BE91A0bdcA49Bbc    Darrell      Douglas  Newton, Petersen and Mathis
# 54  55  f3BEf3Be028166f      Robin         West    Nixon, Blackwell and Sosa
# 0    1  DD37Cf93aecA6Dc     Sheryl          NaN              Rasmussen Group
# 56  57  c8FE57cBBdCDcb2    Phyllis    Maldonado                    Costa PLC
# 47  48  283DFCD0Dba40aF     Gloria       Mccall    Brennan, Acosta and Ramos
# 68  69  421a109cABDf5fa   Virginia       Dudley                   Warren Ltd
# ...

# %%
df.sample(n=10)
# Out:
#      1                2         3 Unnamed: 3                          5  \
# 14  15  6fEaA1b7cab7B6C     Faith       Lutz             Carter-Hancock
# 36  37  889eCf90f68c5Da  Nicholas       Sosa                 Jordan Ltd
# 61  62  9Cf5E6AFE0aeBfd   Shelley     Harris    Prince, Malone and Pugh
# 65  66  fF1b6c9E8Fbf1ff  Fernando    Lambert               Church-Banks
# 59  60  C681dDd0cc422f7     Kelli      Hardy                  Petty Ltd
# 48  49  F4Fc91fEAEad286     Brady      Cohen           Osborne-Erickson
# 47  48  283DFCD0Dba40aF    Gloria     Mccall  Brennan, Acosta and Ramos
# 8    9  C2dE4dEEc489ae0    Sheryl     Meyers             Browning-Simon
# 83  84  78C06E9b6B3DF20      Chad   Davidson             Garcia-Jimenez
# 9   10  8C2811a503C7c5a  Michelle  Gallagher               Beck-Hendrix
#
#                      6                      7                   8  \
# 14           Burchbury              Singapore  (781)861-7180x8306
# ...

# %%
df.head(8)
# Out:
#    1                2        3 Unnamed: 3                                5  \
# 0  1  DD37Cf93aecA6Dc   Sheryl        NaN                  Rasmussen Group
# 1  2  1Ef7b82A4CAAD10  Preston        NaN                      Vega-Gentry
# 2  3  6F94879bDAfE5a6      Roy        NaN                    Murillo-Perry
# 3  4  5Cef8BFA16c5e3c    Linda        NaN  Dominguez, Mcmillan and Donovan
# 4  5  053d585Ab6b3159   Joanna        NaN         Martin, Lang and Andrade
# 5  6  2d08FB17EE273F4    Aimee        NaN                     Steele Group
# 6  7  EA4d384DfDbBf77   Darren       Peck     Lester, Woodard and Mitchell
# 7  8  0e04AFde9f225dE    Brett     Mullen     Sanford, Davenport and Giles
#
#                    6                           7                       8  \
# 0       East Leonard                       Chile            229.077.5154
# 1  East Jimmychester                    Djibouti              5153435776
# ...

# %%
df.tail(9)
# Out:
#       1                2         3 Unnamed: 3                            5  \
# 91   92  98b3aeDcC3B9FF3     Shane      Foley                   Rocha-Hart
# 92   93  aAb6AFc7AfD0fF3    Collin      Ayers                Lamb-Peterson
# 93   94  54B5B5Fe9F1B6C5    Sherry      Young      Lee, Lucero and Johnson
# 94   95  BE91A0bdcA49Bbc   Darrell    Douglas  Newton, Petersen and Mathis
# 95   96  cb8E23e48d22Eae      Karl      Greer                    Carey LLC
# 96   97  CeD220bdAaCfaDf      Lynn   Atkinson        Ware, Burns and Oneal
# 97   98  28CDbC0dFe4b1Db      Fred     Guerra                Schmitt-Jones
# 98   99  c23d1D9EE8DEB0A    Yvonne     Farmer           Fitzgerald-Harrell
# 99  100  2354a0E336A91A1  Clarence     Haynes           Le, Nash and Cross
#
#                    6                7                      8  \
# 91  South Dannymouth          Hungary                  -1692
# 92      South Lonnie         Anguilla       404-645-5351x012
# ...

# %%
df[['6','3','8']]
# Out:
#                     6         3                       8
# 0        East Leonard    Sheryl            229.077.5154
# 1   East Jimmychester   Preston              5153435776
# 2       Isabelborough       Roy                   -1199
# 3          Bensonview     Linda  001-808-617-6467x12895
# 4      West Priscilla    Joanna  001-234-203-0635x76146
# ..                ...       ...                     ...
# 95       East Richard      Karl     (188)169-1674x58692
# 96       New Bradview      Lynn                   -3769
# 97         Ortegaland      Fred    +1-753-067-8419x7170
# 98    Lake Elijahview    Yvonne           (530)311-9786
# 99          Judymouth  Clarence           (753)813-6941
#
# [100 rows x 3 columns]

# %%
df['3']
# Out:
# 0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: 3, Length: 100, dtype: object

# %%
df.filter(regex='5')
# Out:
#                                   5
# 0                   Rasmussen Group
# 1                       Vega-Gentry
# 2                     Murillo-Perry
# 3   Dominguez, Mcmillan and Donovan
# 4          Martin, Lang and Andrade
# ..                              ...
# 95                        Carey LLC
# 96            Ware, Burns and Oneal
# 97                    Schmitt-Jones
# 98               Fitzgerald-Harrell
# 99               Le, Nash and Cross
#
# [100 rows x 1 columns]

# %%
df.loc[5]
# Out:
# 1                                  6
# 2                    2d08FB17EE273F4
# 3                              Aimee
# Unnamed: 3                       NaN
# 5                       Steele Group
# 6                      Chavezborough
# 7             Bosnia and Herzegovina
# 8                                NaN
# 9                       999-728-1637
# 10               louis27@gilbert.com
# 11                         2/25/2020
# 12                               NaN
# Name: 5, dtype: object

# %%
df.iloc[7]
# Out:
# 1                                        8
# 2                          0e04AFde9f225dE
# 3                                    Brett
# Unnamed: 3                          Mullen
# 5             Sanford, Davenport and Giles
# 6                                  Kimport
# 7                                 Bulgaria
# 8                     001-583-352-7197x297
# 9                         001-333-145-0369
# 10                         asnow@colon.com
# 11                               4/12/2021
# 12                                     NaN
# Name: 7, dtype: object

# %%
df.iloc[10:20]
# Out:
#      1                2         3 Unnamed: 3                           5  \
# 10  11  216E205d6eBb815      Carl  Schroeder  Oconnell, Meza and Everett
# 11  12  CEDec94deE6d69B     Jenna     Dodson   Hoffman, Reed and Mcclain
# 12  13  e35426EbDEceaFF    Tracey       Mata              Graham-Francis
# 13  14  A08A8aF8BE9FaD4  Kristine        Cox              Carpenter-Cook
# 14  15  6fEaA1b7cab7B6C     Faith       Lutz              Carter-Hancock
# 15  16  8cad0b4CBceaeec   Miranda    Beasley          Singleton and Sons
# 16  17  a5DC21AE3a21eaA  Caroline      Foley             Winters-Mendoza
# 17  18  F8Aa9d6DfcBeeF8      Greg       Mata               Valentine LLC
# 18  19  F160f5Db3EfE973  Clifford   Jacobson                   Simon LLC
# 19  20  0F60FF3DdCd7aB0    Joanna       Kirk              Mays-Mccormick
#
#                     6                                             7  \
# 10       Shannonville                                      Guernsey
# ...

# %%
df.iloc[:,[1,2,3]]
# Out:
#                   2         3 Unnamed: 3
# 0   DD37Cf93aecA6Dc    Sheryl        NaN
# 1   1Ef7b82A4CAAD10   Preston        NaN
# 2   6F94879bDAfE5a6       Roy        NaN
# 3   5Cef8BFA16c5e3c     Linda        NaN
# 4   053d585Ab6b3159    Joanna        NaN
# ..              ...       ...        ...
# 95  cb8E23e48d22Eae      Karl      Greer
# 96  CeD220bdAaCfaDf      Lynn   Atkinson
# 97  28CDbC0dFe4b1Db      Fred     Guerra
# 98  c23d1D9EE8DEB0A    Yvonne     Farmer
# 99  2354a0E336A91A1  Clarence     Haynes
#
# [100 rows x 3 columns]

# %%
df.loc[:,'9':'9']
# Out:
#                          9
# 0         397.884.0519x718
# 1         686-620-1820x944
# 2      (496)978-3969x58947
# 3                    -9892
# 4    001-199-446-3860x3486
# ..                     ...
# 95    001-841-293-3519x614
# 96            605.413.3198
# 97   +1-632-666-7507x92121
# 98  001-869-452-0943x12424
# 99            783.639.1472
#
# [100 rows x 1 columns]

# %%
df.iat[1,9]
# Out:
# 'vmata@colon.com'

# %%
df.at[4,'10']
# Out:
# 'colinalvarado@miles.net'

# %%
len(df)
# Out:
# 100

# %%
df.shape
# Out:
# (100, 12)

# %%
df['6'].nunique()
# Out:
# 100

# %%
df.groupby(by="9")

# %%
df.expanding()
# Out:
# Expanding [min_periods=1,axis=0,method=single]

# %%
df.rolling(9)
# Out:
# Rolling [window=9,center=False,axis=0,method=single]

# %%
df.fillna(9796789798)
# Out:
#       1                2         3  Unnamed: 3  \
# 0     1  DD37Cf93aecA6Dc    Sheryl  9796789798
# 1     2  1Ef7b82A4CAAD10   Preston  9796789798
# 2     3  6F94879bDAfE5a6       Roy  9796789798
# 3     4  5Cef8BFA16c5e3c     Linda  9796789798
# 4     5  053d585Ab6b3159    Joanna  9796789798
# ..  ...              ...       ...         ...
# 95   96  cb8E23e48d22Eae      Karl       Greer
# 96   97  CeD220bdAaCfaDf      Lynn    Atkinson
# 97   98  28CDbC0dFe4b1Db      Fred      Guerra
# 98   99  c23d1D9EE8DEB0A    Yvonne      Farmer
# 99  100  2354a0E336A91A1  Clarence      Haynes
#
#                                   5                  6  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# ...

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.merge(d,df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12208\3798605483.py in ?()
# ----> 1 df.merge(d,df)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9839         validate: str | None = None,
#    9840     ) -> DataFrame:
#    9841         from pandas.core.reshape.merge import merge
#    9842
# -> 9843         return merge(
#    9844             self,
#    9845             right,
#    9846             how=how,
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
# ...

# %%
df.plot.scatter(x='1',y='1')
# Out:
# <Axes: xlabel='1', ylabel='1'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df.plot.scattter(x='1',y='1')
#
# AttributeError: 'PlotAccessor' object has no attribute 'scattter'
